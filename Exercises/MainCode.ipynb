# %%
from VehicleTracker2 import VehicleTracker2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
test_img = mpimg.imread('./test_images/test6.jpg')

# %%
trkr=VehicleTracker2(test_img.shape,heatmap_threshold=1)

# %%
final_img,init_img,box_list,heatmap=trkr.debug_process(test_img,2)

# %%
plt.imshow(test_img)
plt.show()

# %%
plt.imshow(init_img)
plt.show()

# %%
plt.imshow(heatmap,cmap='hot')
plt.show()

# %%
plt.imshow(trkr.heatmapper.heatmap)
plt.show()

# %%
plt.imshow(final_img)
plt.show()

# %%
vehicle_trkr=VehicleTracker2(test_img.shape,heatmap_threshold=20)
from moviepy.editor import VideoFileClip
def process_movie(input_path, output_path,duration):
    clip = VideoFileClip(input_path)
    if duration > 0:
        out_clip = clip.fl_image(vehicle_trkr.process).subclip(5,20)
    else:
        out_clip = clip.fl_image(vehicle_trkr.process)
    out_clip.write_videofile(output_path, audio=False)

process_movie("../project_video.mp4", "../project_video_out.mp4",1)
# Out:
# [MoviePy] >>>> Building video ../project_video_out.mp4
# [MoviePy] Writing video ../project_video_out.mp4
# 100%|█████████▉| 375/376 [08:31<00:01,  1.35s/it]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ../project_video_out.mp4

# %%
plt.imshow(vehicle_trkr.heatmapper.heatmap)
plt.show()
